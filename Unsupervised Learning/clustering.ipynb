# %% [markdown]
# Clustering vehicles based on their specifications.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
np.random.seed(0)
data_size = 300
data = {
    'weight': np.random.randint(1000, 3000, data_size),
    'Engine Size':np.random.uniform(1.0,4.0,data_size),
    'HorsePower':np.random.randint(50,300,data_size)
}

# %%
data_df = pd.DataFrame(data)
print(data_df.head())
x=data_df
# Out:
#    weight  Engine Size  HorsePower
# 0    1684     3.544025          62
# 1    1559     3.421957         168
# 2    2653     2.707302          96
# 3    2216     2.221550         168
# 4    1835     1.207501          82

# %%
kmeans =  KMeans(n_clusters=3, random_state=42)
kmeans.fit(x)
# Out:
# KMeans(n_clusters=3, random_state=42)

# %%
plt.scatter(data_df['weight'],data_df['HorsePower'])
plt.xlabel('Weight')
plt.ylabel('HorsePower')
plt.title("Vehicle Clusters")
plt.show()
