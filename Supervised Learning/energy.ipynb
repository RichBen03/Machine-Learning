# %% [markdown]
# PREDICTING ENERGY EFFICIENCY OF BUILDINGS

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
import warnings

warnings.filterwarnings('ignore')

# %%
np.random.seed(0)
data_size = 500
data = {
    'WallArea' : np.random.randint(200,300,data_size) , 
    'RoofArea': np.random.randint(100,200,data_size),
    'OverallHeight': np.random.uniform(3,10,data_size),
    'GlazingArea':np.random.uniform(0,1,data_size),
    'EnergyEfficiency': np.random.uniform(10,50, data_size)
}

# %%
data_df = pd.DataFrame(data)
print(data_df.tail())
# Out:
#      WallArea  RoofArea  OverallHeight  GlazingArea  EnergyEfficiency
# 495       203       126       6.138700     0.953563         41.908477
# 496       212       148       5.822030     0.084288         10.007469
# 497       258       171       3.482163     0.951102         48.183791
# 498       201       154       9.601997     0.034989         36.500579
# 499       200       196       8.508679     0.538944         22.425914

# %%
X = data_df.drop('EnergyEfficiency',axis=1)
Y = data_df('EnergyEfficiency')

# %%
sns.pairplot(data_df,x_vars=["WallArea","RoofArea","OverallHeight","GlazingArea"], y_vars="EnergyEfficiency",height=4, aspect=1, kind='scatter')
plt.show()
